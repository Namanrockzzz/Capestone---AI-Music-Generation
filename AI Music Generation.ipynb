# %%
# %config IPCompleter.use_jedi = False

# %% [markdown]
# ### Import Required Libraries

# %%
from music21 import converter, instrument, note, chord, stream
import glob
import pickle
import numpy as np

# %% [markdown]
# ### Reading a Music File (midi format)

# %%
midi = converter.parse('piano_tunes/BlueStone_LastDungeon.mid')

# %%
midi
# Out:
# <music21.stream.Score 0x28d606ce908>

# %%
midi.show('midi') # For listening to songs
# Out:
#                 <div id='midiPlayerDiv11923'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv11923');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
midi.show('text') # Whole music in text format
# Out:
# {0.0} <music21.stream.Part 0x28d606d55c8>
#     {0.0} <music21.instrument.Piano 'Right Hand: Piano'>
#     {0.0} <music21.instrument.Piano 'Right Hand: Piano'>
#     {0.0} <music21.tempo.MetronomeMark Quarter=124.0>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x28d606d9c08>
#         {0.0} <music21.chord.Chord C#4 E4 A4>
#         {7.75} <music21.note.Rest rest>
#         {8.0} <music21.chord.Chord D4 F4 B-4>
#         {15.75} <music21.note.Rest rest>
#         {16.0} <music21.chord.Chord E-4 F#4 B4>
#         {23.75} <music21.note.Rest rest>
#         {24.0} <music21.chord.Chord E4 G4 C5>
#         {31.75} <music21.note.Rest rest>
#         {32.0} <music21.chord.Chord C#4 E4 A4>
#         {35.75} <music21.note.Rest rest>
#         {39.0} <music21.chord.Chord C4 E4 A4>
#         {39.3333} <music21.chord.Chord C4 E4 A4>
#         {39.6667} <music21.chord.Chord C4 E4 A4>
#         {40.0} <music21.chord.Chord B3 D4 G4>
#         {41.75} <music21.note.Rest rest>
#         {42.0} <music21.chord.Chord D4 G4 B4>
#         {42.75} <music21.note.Rest rest>
#         {43.0} <music21.chord.Chord G4 B4 D5>
#         {43.75} <music21.note.Rest rest>
#         {44.0} <music21.chord.Chord B4 D5 G5>
#         {45.75} <music21.note.Rest rest>
#         {46.0} <music21.chord.Chord D5 G5 B5>
#         {46.75} <music21.note.Rest rest>
#         {47.0} <music21.chord.Chord B3 D4 G4>
#         {47.3333} <music21.chord.Chord B3 D4 G4>
#         {47.6667} <music21.chord.Chord B3 D4 G4>
#         {48.0} <music21.chord.Chord C4 E4 A4>
#         {49.75} <music21.note.Rest rest>
#         {50.0} <music21.chord.Chord A4 E5>
#         {51.75} <music21.note.Rest rest>
#         {52.0} <music21.chord.Chord E4 C5>
#         {53.75} <music21.note.Rest rest>
#         {54.0} <music21.chord.Chord C4 A4>
#         {54.75} <music21.note.Rest rest>
#         {55.0} <music21.chord.Chord C4 E4 A4>
#         {55.3333} <music21.chord.Chord C4 E4 A4>
#         {55.6667} <music21.chord.Chord C4 E4 A4>
#         {56.0} <music21.chord.Chord D4 F4 B-4>
#         {56.75} <music21.note.Rest rest>
#         {57.0} <music21.chord.Chord C4 E4 A4>
#         {57.25} <music21.note.Rest rest>
#         {57.5} <music21.chord.Chord A3 E4>
#         {58.0} <music21.chord.Chord C4 E-4 G#4 C5>
#         {58.5} <music21.chord.Chord C4 E-4>
#         {59.0} <music21.chord.Chord C4 E4 A4>
#         {59.25} <music21.note.Note B>
#         {59.5} <music21.note.Note A>
#         {60.0} <music21.chord.Chord B3 D4 G#4>
#         {60.75} <music21.note.Rest rest>
#         {61.0} <music21.chord.Chord A3 C4 A4>
#         {62.75} <music21.note.Rest rest>
#         {63.0} <music21.chord.Chord C4 E4 A4>
#         {63.3333} <music21.chord.Chord C4 E4 A4>
#         {63.6667} <music21.chord.Chord C4 E4 A4>
#         {64.0} <music21.chord.Chord D4 F4 B-4>
#         {64.75} <music21.note.Rest rest>
#         {65.0} <music21.chord.Chord C4 E4 A4>
#         {65.25} <music21.note.Rest rest>
#         {65.5} <music21.chord.Chord A3 E4>
#         {66.0} <music21.chord.Chord C4 E-4 G#4 C5>
#         {66.5} <music21.chord.Chord C4 E-4>
#         {67.0} <music21.chord.Chord C4 E4 A4>
#         {67.25} <music21.note.Note B>
#         {67.5} <music21.note.Note A>
#         {68.0} <music21.chord.Chord B3 D4 G#4>
#         {68.75} <music21.note.Rest rest>
#         {69.0} <music21.chord.Chord A3 C4 A4>
#         {70.75} <music21.note.Rest rest>
#         {71.0} <music21.chord.Chord A4 C5 E5>
#         {71.3333} <music21.chord.Chord A4 C5 E5>
#         {71.6667} <music21.chord.Chord A4 C5 E5>
#         {72.0} <music21.chord.Chord A4 B4 E-5>
#         {72.75} <music21.note.Rest rest>
#         {73.0} <music21.chord.Chord A4 C5 E5>
#         {73.25} <music21.note.Rest rest>
#         {74.0} <music21.chord.Chord E4 C5>
#         {74.5} <music21.chord.Chord C4 E4>
#         {75.0} <music21.chord.Chord D4 E4 G#4>
#         {75.3333} <music21.chord.Chord D4 E4 G#4>
#         {75.6667} <music21.chord.Chord D4 E4 G#4>
#         {76.0} <music21.chord.Chord C4 E4 A4>
#         {78.75} <music21.note.Rest rest>
#         {79.0} <music21.chord.Chord A4 C5 E5>
#         {79.3333} <music21.chord.Chord A4 C5 E5>
#         {79.6667} <music21.chord.Chord A4 C5 E5>
#         {80.0} <music21.chord.Chord A4 B4 E-5>
#         {80.75} <music21.note.Rest rest>
#         {81.0} <music21.chord.Chord A4 C5 E5>
#         {81.25} <music21.note.Rest rest>
#         {83.0} <music21.chord.Chord D4 E4 G#4>
#         {83.3333} <music21.chord.Chord D4 E4 G#4>
#         {83.6667} <music21.chord.Chord D4 E4 G#4>
#         {84.0} <music21.chord.Chord C4 E4 A4>
#         {87.75} <music21.note.Rest rest>
#         {88.0} <music21.chord.Chord C4 E4 A4>
#         {88.75} <music21.note.Rest rest>
#         {89.0} <music21.chord.Chord D4 G#4 B4>
#         {89.5} <music21.chord.Chord E4 A4 C5>
#         {90.0} <music21.chord.Chord F4 B4 D5>
#         {90.75} <music21.note.Rest rest>
#         {91.0} <music21.chord.Chord E4 A4 C5>
#         {91.5} <music21.chord.Chord D4 G#4 B4>
#         {92.0} <music21.chord.Chord E4 A4 C5>
#         {92.75} <music21.note.Rest rest>
#         {93.0} <music21.chord.Chord C4 E4 A4>
#         {95.75} <music21.note.Rest rest>
#         {99.0} <music21.chord.Chord E4 A4 C5>
#         {99.3333} <music21.chord.Chord E4 B4 D5>
#         {99.6667} <music21.chord.Chord E4 C5 E5>
#         {100.0} <music21.chord.Chord G#4 D5 F5>
#         {100.75} <music21.note.Rest rest>
#         {101.0} <music21.chord.Chord D6 G#6 D7>
#         {101.3333} <music21.chord.Chord D6 G#6 D7>
#         {101.6667} <music21.chord.Chord D6 G#6 D7>
#         {102.0} <music21.chord.Chord D6 G#6 D7>
#         {102.75} <music21.note.Rest rest>
#         {103.0} <music21.chord.Chord E4 G#4 B4>
#         {103.3333} <music21.chord.Chord E4 A4 C5>
#         {103.6667} <music21.chord.Chord G#4 B4 D5>
#         {104.0} <music21.chord.Chord A4 C5 E5>
#         {104.75} <music21.note.Rest rest>
#         {105.0} <music21.chord.Chord C6 A6 C7>
#         {105.3333} <music21.chord.Chord C6 A6 C7>
#         {105.6667} <music21.chord.Chord C6 A6 C7>
#         {106.0} <music21.chord.Chord C6 A6 C7>
#         {106.5} <music21.chord.Chord C4 E4 A4>
#         {107.0} <music21.chord.Chord D4 G#4 B4>
#         {107.5} <music21.chord.Chord E4 A4 C5>
#         {108.0} <music21.note.Note D>
#         {110.75} <music21.note.Rest rest>
#         {111.0} <music21.chord.Chord D4 G#4 C5>
#         {112.0} <music21.chord.Chord C4 E4 A4>
#         {115.75} <music21.note.Rest rest>
#         {120.0} <music21.chord.Chord F5 A5>
#         {120.75} <music21.note.Rest rest>
#         {121.0} <music21.chord.Chord E5 G5>
#         {121.75} <music21.note.Rest rest>
#         {122.0} <music21.chord.Chord D5 F5 D6>
#         {122.75} <music21.note.Rest rest>
#         {123.0} <music21.chord.Chord E5 G5>
#         {123.75} <music21.note.Rest rest>
#         {124.0} <music21.note.Note F>
#         {127.75} <music21.note.Rest rest>
#         {130.0} <music21.note.Note E>
#         {131.75} <music21.note.Rest rest>
#         {132.0} <music21.chord.Chord F4 A4>
#         {132.75} <music21.note.Rest rest>
#         {133.0} <music21.chord.Chord G4 B4>
#         {133.5} <music21.chord.Chord A4 C5>
#         {134.0} <music21.chord.Chord B4 D5>
#         {134.75} <music21.note.Rest rest>
#         {135.0} <music21.chord.Chord A4 C5>
#         {135.5} <music21.chord.Chord G4 B4>
#         {136.0} <music21.chord.Chord A4 C5>
#         {136.75} <music21.note.Rest rest>
#         {137.0} <music21.chord.Chord F4 A4>
#         {139.75} <music21.note.Rest rest>
#         {144.0} <music21.note.Note F>
#         {147.75} <music21.note.Rest rest>
#         {148.0} <music21.chord.Chord E4 G4 E5>
#         {148.75} <music21.note.Rest rest>
#         {149.0} <music21.chord.Chord F4 C5 F5>
#         {149.5} <music21.chord.Chord G4 C5 G5>
#         {150.0} <music21.chord.Chord G#4 B4 F5 G#5>
#         {150.75} <music21.note.Rest rest>
#         {151.0} <music21.chord.Chord G4 D5>
#         {151.5} <music21.chord.Chord G#4 D5 F5>
#         {152.0} <music21.chord.Chord G4 C5 E5>
#         {154.75} <music21.note.Rest rest>
#         {155.0} <music21.chord.Chord G#4 B4 D5>
#         {155.3333} <music21.chord.Chord C5 E5>
#         {155.6667} <music21.chord.Chord D5 F5>
#         {156.0} <music21.chord.Chord A4 C5 E5>
#         {157.75} <music21.note.Rest rest>
#         {158.0} <music21.chord.Chord G#4 D5>
#         {158.5} <music21.note.Note C>
#         {159.0} <music21.chord.Chord D4 B4>
#         {159.5} <music21.note.Note E>
#         {160.0} <music21.chord.Chord C4 E4 A4>
#         {163.75} <music21.note.Rest rest>
#         {167.0} <music21.chord.Chord B3 D4 G4>
#         {167.3333} <music21.chord.Chord C4 A4>
#         {167.6667} <music21.chord.Chord D4 B4>
#         {168.0} <music21.chord.Chord C4 E4 A4>
#         {171.75} <music21.note.Rest rest>
#         {175.0} <music21.chord.Chord C4 E4 A4>
#         {175.3333} <music21.chord.Chord C4 E4 A4>
#         {175.6667} <music21.chord.Chord C4 E4 A4>
#         {176.0} <music21.chord.Chord B3 D4 G4>
#         {177.75} <music21.note.Rest rest>
#         {178.0} <music21.chord.Chord D4 G4 B4>
#         {178.75} <music21.note.Rest rest>
#         {179.0} <music21.chord.Chord G4 B4 D5>
#         {179.75} <music21.note.Rest rest>
#         {180.0} <music21.chord.Chord B4 D5 G5>
#         {181.75} <music21.note.Rest rest>
#         {182.0} <music21.chord.Chord D5 G5 B5>
#         {182.75} <music21.note.Rest rest>
#         {183.0} <music21.chord.Chord B3 D4 G4>
#         {183.3333} <music21.chord.Chord B3 D4 G4>
#         {183.6667} <music21.chord.Chord B3 D4 G4>
#         {184.0} <music21.chord.Chord C4 E4 A4>
#         {185.75} <music21.note.Rest rest>
#         {186.0} <music21.chord.Chord A4 E5>
#         {187.75} <music21.note.Rest rest>
#         {188.0} <music21.chord.Chord E4 C5>
#         {189.75} <music21.note.Rest rest>
#         {190.0} <music21.chord.Chord C4 A4>
#         {190.75} <music21.note.Rest rest>
#         {191.0} <music21.chord.Chord C4 E4 A4>
#         {191.3333} <music21.chord.Chord C4 E4 A4>
#         {191.6667} <music21.chord.Chord C4 E4 A4>
#         {192.0} <music21.chord.Chord D4 F4 B-4>
#         {192.75} <music21.note.Rest rest>
#         {193.0} <music21.chord.Chord C4 E4 A4>
#         {193.25} <music21.note.Rest rest>
#         {193.5} <music21.chord.Chord A3 E4>
#         {194.0} <music21.chord.Chord C4 E-4 G#4 C5>
#         {194.5} <music21.chord.Chord C4 E-4>
#         {195.0} <music21.chord.Chord C4 E4 A4>
#         {195.25} <music21.note.Note B>
#         {195.5} <music21.note.Note A>
#         {196.0} <music21.chord.Chord B3 D4 G#4>
#         {196.75} <music21.note.Rest rest>
#         {197.0} <music21.chord.Chord A3 C4 A4>
#         {198.75} <music21.note.Rest rest>
#         {199.0} <music21.chord.Chord C4 E4 A4>
#         {199.3333} <music21.chord.Chord C4 E4 A4>
#         {199.6667} <music21.chord.Chord C4 E4 A4>
#         {200.0} <music21.chord.Chord D4 F4 B-4>
#         {200.75} <music21.note.Rest rest>
#         {201.0} <music21.chord.Chord C4 E4 A4>
#         {201.25} <music21.note.Rest rest>
#         {201.5} <music21.chord.Chord A3 E4>
#         {202.0} <music21.chord.Chord C4 E-4 G#4 C5>
#         {202.5} <music21.chord.Chord C4 E-4>
#         {203.0} <music21.chord.Chord C4 E4 A4>
#         {203.25} <music21.note.Note B>
#         {203.5} <music21.note.Note A>
#         {204.0} <music21.chord.Chord B3 D4 G#4>
#         {204.75} <music21.note.Rest rest>
#         {205.0} <music21.chord.Chord A3 C4 A4>
#         {206.75} <music21.note.Rest rest>
#         {207.0} <music21.chord.Chord A4 C5 E5>
#         {207.3333} <music21.chord.Chord A4 C5 E5>
#         {207.6667} <music21.chord.Chord A4 C5 E5>
#         {208.0} <music21.chord.Chord A4 B4 E-5>
#         {208.75} <music21.note.Rest rest>
#         {209.0} <music21.chord.Chord A4 C5 E5>
#         {209.25} <music21.note.Rest rest>
#         {210.0} <music21.chord.Chord E4 C5>
#         {210.5} <music21.chord.Chord C4 E4>
#         {211.0} <music21.chord.Chord D4 E4 G#4>
#         {211.3333} <music21.chord.Chord D4 E4 G#4>
#         {211.6667} <music21.chord.Chord D4 E4 G#4>
#         {212.0} <music21.chord.Chord C4 E4 A4>
#         {214.75} <music21.note.Rest rest>
#         {215.0} <music21.chord.Chord A4 C5 E5>
#         {215.3333} <music21.chord.Chord A4 C5 E5>
#         {215.6667} <music21.chord.Chord A4 C5 E5>
#         {216.0} <music21.chord.Chord A4 B4 E-5>
#         {216.75} <music21.note.Rest rest>
#         {217.0} <music21.chord.Chord A4 C5 E5>
#         {217.25} <music21.note.Rest rest>
#         {219.0} <music21.chord.Chord D4 E4 G#4>
#         {219.3333} <music21.chord.Chord D4 E4 G#4>
#         {219.6667} <music21.chord.Chord D4 E4 G#4>
#         {220.0} <music21.chord.Chord C4 E4 A4>
#         {223.75} <music21.note.Rest rest>
#         {224.0} <music21.chord.Chord C4 E4 A4>
#         {224.75} <music21.note.Rest rest>
#         {225.0} <music21.chord.Chord D4 G#4 B4>
#         {225.5} <music21.chord.Chord E4 A4 C5>
#         {226.0} <music21.chord.Chord F4 B4 D5>
#         {226.75} <music21.note.Rest rest>
#         {227.0} <music21.chord.Chord E4 A4 C5>
#         {227.5} <music21.chord.Chord D4 G#4 B4>
#         {228.0} <music21.chord.Chord E4 A4 C5>
#         {228.75} <music21.note.Rest rest>
#         {229.0} <music21.chord.Chord C4 E4 A4>
#         {231.75} <music21.note.Rest rest>
#         {235.0} <music21.chord.Chord E4 A4 C5>
#         {235.3333} <music21.chord.Chord E4 B4 D5>
#         {235.6667} <music21.chord.Chord E4 C5 E5>
#         {236.0} <music21.chord.Chord G#4 D5 F5>
#         {236.75} <music21.note.Rest rest>
#         {237.0} <music21.chord.Chord D6 G#6 D7>
#         {237.3333} <music21.chord.Chord D6 G#6 D7>
#         {237.6667} <music21.chord.Chord D6 G#6 D7>
#         {238.0} <music21.chord.Chord D6 G#6 D7>
#         {238.75} <music21.note.Rest rest>
#         {239.0} <music21.chord.Chord E4 G#4 B4>
#         {239.3333} <music21.chord.Chord E4 A4 C5>
#         {239.6667} <music21.chord.Chord G#4 B4 D5>
#         {240.0} <music21.chord.Chord A4 C5 E5>
#         {240.75} <music21.note.Rest rest>
#         {241.0} <music21.chord.Chord C6 A6 C7>
#         {241.3333} <music21.chord.Chord C6 A6 C7>
#         {241.6667} <music21.chord.Chord C6 A6 C7>
#         {242.0} <music21.chord.Chord C6 A6 C7>
#         {242.5} <music21.chord.Chord C4 E4 A4>
#         {243.0} <music21.chord.Chord D4 G#4 B4>
#         {243.5} <music21.chord.Chord E4 A4 C5>
#         {244.0} <music21.note.Note D>
#         {246.75} <music21.note.Rest rest>
#         {247.0} <music21.chord.Chord D4 G#4 C5>
#         {248.0} <music21.chord.Chord C4 E4 A4>
#         {251.75} <music21.note.Rest rest>
#         {256.0} <music21.chord.Chord F5 A5>
#         {256.75} <music21.note.Rest rest>
#         {257.0} <music21.chord.Chord E5 G5>
#         {257.75} <music21.note.Rest rest>
#         {258.0} <music21.chord.Chord D5 F5 D6>
#         {258.75} <music21.note.Rest rest>
#         {259.0} <music21.chord.Chord E5 G5>
#         {259.75} <music21.note.Rest rest>
#         {260.0} <music21.note.Note F>
#         {263.75} <music21.note.Rest rest>
#         {266.0} <music21.note.Note E>
#         {267.75} <music21.note.Rest rest>
#         {268.0} <music21.chord.Chord F4 A4>
#         {268.75} <music21.note.Rest rest>
#         {269.0} <music21.chord.Chord G4 B4>
#         {269.5} <music21.chord.Chord A4 C5>
#         {270.0} <music21.chord.Chord B4 D5>
#         {270.75} <music21.note.Rest rest>
#         {271.0} <music21.chord.Chord A4 C5>
#         {271.5} <music21.chord.Chord G4 B4>
#         {272.0} <music21.chord.Chord A4 C5>
#         {272.75} <music21.note.Rest rest>
#         {273.0} <music21.chord.Chord F4 A4>
#         {275.75} <music21.note.Rest rest>
#         {280.0} <music21.note.Note F>
#         {283.75} <music21.note.Rest rest>
#         {284.0} <music21.chord.Chord E4 G4 E5>
#         {284.75} <music21.note.Rest rest>
#         {285.0} <music21.chord.Chord F4 C5 F5>
#         {285.5} <music21.chord.Chord G4 C5 G5>
#         {286.0} <music21.chord.Chord G#4 B4 F5 G#5>
#         {286.75} <music21.note.Rest rest>
#         {287.0} <music21.chord.Chord G4 D5>
#         {287.5} <music21.chord.Chord G#4 D5 F5>
#         {288.0} <music21.chord.Chord G4 C5 E5>
#         {290.75} <music21.note.Rest rest>
#         {291.0} <music21.chord.Chord G#4 B4 D5>
#         {291.3333} <music21.chord.Chord C5 E5>
#         {291.6667} <music21.chord.Chord D5 F5>
#         {292.0} <music21.chord.Chord A4 C5 E5>
#         {293.75} <music21.note.Rest rest>
#         {294.0} <music21.chord.Chord G#4 D5>
#         {294.5} <music21.note.Note C>
#         {295.0} <music21.chord.Chord D4 B4>
#         {295.5} <music21.note.Note E>
#         {296.0} <music21.chord.Chord C4 E4 A4>
#         {299.75} <music21.note.Rest rest>
#         {303.0} <music21.chord.Chord B3 D4 G4>
#         {303.3333} <music21.chord.Chord C4 A4>
#         {303.6667} <music21.chord.Chord D4 B4>
#         {304.0} <music21.chord.Chord C4 E4 A4>
#     {0.0} <music21.stream.Voice 0x28d68b92788>
#         {0.0} <music21.note.Rest rest>
#         {108.0} <music21.chord.Chord A4 D5>
#         {108.75} <music21.note.Rest rest>
#         {109.0} <music21.note.Note F>
#         {109.75} <music21.note.Rest rest>
#         {110.0} <music21.chord.Chord B3 D4>
#         {110.75} <music21.note.Rest rest>
#         {121.0} <music21.note.Note B>
#         {121.5} <music21.note.Note C>
#         {122.0} <music21.note.Rest rest>
#         {123.0} <music21.note.Note C>
#         {123.5} <music21.note.Note B>
#         {124.0} <music21.chord.Chord A5 C6>
#         {124.75} <music21.note.Rest rest>
#         {125.0} <music21.note.Note A>
#         {127.75} <music21.note.Rest rest>
#         {144.0} <music21.chord.Chord A4 C5>
#         {144.75} <music21.note.Rest rest>
#         {145.0} <music21.chord.Chord A4 D5>
#         {145.5} <music21.chord.Chord A4 E5>
#         {146.0} <music21.chord.Chord G#4 F5>
#         {146.75} <music21.note.Rest rest>
#         {147.0} <music21.chord.Chord G#4 E5>
#         {147.5} <music21.chord.Chord G#4 D5>
#         {148.0} <music21.note.Rest rest>
#         {244.0} <music21.chord.Chord A4 D5>
#         {244.75} <music21.note.Rest rest>
#         {245.0} <music21.note.Note F>
#         {245.75} <music21.note.Rest rest>
#         {246.0} <music21.chord.Chord B3 D4>
#         {246.75} <music21.note.Rest rest>
#         {257.0} <music21.note.Note B>
#         {257.5} <music21.note.Note C>
#         {258.0} <music21.note.Rest rest>
#         {259.0} <music21.note.Note C>
#         {259.5} <music21.note.Note B>
#         {260.0} <music21.chord.Chord A5 C6>
#         {260.75} <music21.note.Rest rest>
#         {261.0} <music21.note.Note A>
#         {263.75} <music21.note.Rest rest>
#         {280.0} <music21.chord.Chord A4 C5>
#         {280.75} <music21.note.Rest rest>
#         {281.0} <music21.chord.Chord A4 D5>
#         {281.5} <music21.chord.Chord A4 E5>
#         {282.0} <music21.chord.Chord G#4 F5>
#         {282.75} <music21.note.Rest rest>
#         {283.0} <music21.chord.Chord G#4 E5>
#         {283.5} <music21.chord.Chord G#4 D5>
#         {284.0} <music21.note.Rest rest>
#     {0.0} <music21.stream.Voice 0x28d68bde548>
#         {109.0} <music21.note.Note C>
#         {109.5} <music21.note.Note B->
#         {110.0} <music21.note.Note G#>
#         {110.5} <music21.note.Note E>
#         {245.0} <music21.note.Note C>
#         {245.5} <music21.note.Note B->
#         {246.0} <music21.note.Note G#>
#         {246.5} <music21.note.Note E>
# {0.0} <music21.stream.Part 0x28d68be3fc8>
#     {0.0} <music21.instrument.Piano 'Left Hand: Piano'>
#     {0.0} <music21.instrument.Piano 'Left Hand: Piano'>
#     {0.0} <music21.tempo.MetronomeMark Quarter=124.0>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.note.Note A>
#     {1.3333} <music21.note.Rest rest>
#     {1.5} <music21.note.Note A>
#     {2.25} <music21.note.Rest rest>
#     {2.5} <music21.note.Note A>
#     {3.25} <music21.note.Rest rest>
#     {3.5} <music21.note.Note A>
#     {4.0} <music21.note.Note A>
#     {5.3333} <music21.note.Rest rest>
#     {5.5} <music21.note.Note A>
#     {6.25} <music21.note.Rest rest>
#     {6.5} <music21.note.Note A>
#     {7.0} <music21.note.Note A>
#     {7.75} <music21.note.Rest rest>
#     {8.0} <music21.note.Note A>
#     {9.3333} <music21.note.Rest rest>
#     {9.5} <music21.note.Note A>
#     {10.25} <music21.note.Rest rest>
#     {10.5} <music21.note.Note A>
#     {11.25} <music21.note.Rest rest>
#     {11.5} <music21.note.Note A>
#     {12.0} <music21.note.Note A>
#     {13.3333} <music21.note.Rest rest>
#     {13.5} <music21.note.Note A>
#     {14.25} <music21.note.Rest rest>
#     {14.5} <music21.note.Note A>
#     {15.0} <music21.note.Note A>
#     {15.75} <music21.note.Rest rest>
#     {16.0} <music21.note.Note A>
#     {17.3333} <music21.note.Rest rest>
#     {17.5} <music21.note.Note A>
#     {18.25} <music21.note.Rest rest>
#     {18.5} <music21.note.Note A>
#     {19.25} <music21.note.Rest rest>
#     {19.5} <music21.note.Note A>
#     {20.0} <music21.note.Note A>
#     {21.3333} <music21.note.Rest rest>
#     {21.5} <music21.note.Note A>
#     {22.25} <music21.note.Rest rest>
#     {22.5} <music21.note.Note A>
#     {23.0} <music21.note.Note A>
#     {23.75} <music21.note.Rest rest>
#     {24.0} <music21.note.Note A>
#     {25.3333} <music21.note.Rest rest>
#     {25.5} <music21.note.Note A>
#     {26.25} <music21.note.Rest rest>
#     {26.5} <music21.note.Note A>
#     {27.25} <music21.note.Rest rest>
#     {27.5} <music21.note.Note A>
#     {28.0} <music21.note.Note A>
#     {29.3333} <music21.note.Rest rest>
#     {29.5} <music21.note.Note A>
#     {30.25} <music21.note.Rest rest>
#     {30.5} <music21.note.Note A>
#     {31.0} <music21.note.Note A>
#     {31.75} <music21.note.Rest rest>
#     {32.0} <music21.chord.Chord A1 A2>
#     {33.75} <music21.note.Rest rest>
#     {34.0} <music21.chord.Chord A1 A2>
#     {35.75} <music21.note.Rest rest>
#     {36.0} <music21.chord.Chord A1 A2>
#     {37.75} <music21.note.Rest rest>
#     {38.0} <music21.chord.Chord A1 A2>
#     {39.75} <music21.note.Rest rest>
#     {40.0} <music21.note.Note A>
#     {40.75} <music21.note.Rest rest>
#     {41.0} <music21.note.Note E>
#     {41.3333} <music21.note.Note E>
#     {41.6667} <music21.note.Note E>
#     {42.0} <music21.note.Note A>
#     {42.75} <music21.note.Rest rest>
#     {43.0} <music21.note.Note E>
#     {43.3333} <music21.note.Note E>
#     {43.6667} <music21.note.Note E>
#     {44.0} <music21.note.Note A>
#     {44.75} <music21.note.Rest rest>
#     {45.0} <music21.note.Note E>
#     {45.3333} <music21.note.Note E>
#     {45.6667} <music21.note.Note E>
#     {46.0} <music21.note.Note G>
#     {46.5} <music21.note.Note G>
#     {46.6667} <music21.note.Note G>
#     {46.9167} <music21.note.Rest rest>
#     {47.0} <music21.note.Note D>
#     {47.3333} <music21.note.Note E>
#     {47.6667} <music21.note.Note C>
#     {48.0} <music21.note.Note A>
#     {48.75} <music21.note.Rest rest>
#     {49.0} <music21.note.Note E>
#     {49.3333} <music21.note.Note E>
#     {49.6667} <music21.note.Note E>
#     {50.0} <music21.note.Note A>
#     {50.75} <music21.note.Rest rest>
#     {51.0} <music21.note.Note G>
#     {51.3333} <music21.note.Note B>
#     {51.6667} <music21.note.Note G>
#     {52.0} <music21.note.Note A>
#     {52.75} <music21.note.Rest rest>
#     {53.0} <music21.note.Note F#>
#     {53.3333} <music21.note.Note G>
#     {53.6667} <music21.note.Note G#>
#     {54.0} <music21.note.Note A>
#     {54.75} <music21.note.Rest rest>
#     {55.0} <music21.note.Note A>
#     {55.3333} <music21.note.Note A>
#     {55.6667} <music21.note.Note A>
#     {56.0} <music21.note.Note B->
#     {56.75} <music21.note.Rest rest>
#     {57.0} <music21.note.Note A>
#     {57.25} <music21.note.Rest rest>
#     {58.0} <music21.chord.Chord G#2 G#3>
#     {58.75} <music21.note.Rest rest>
#     {59.0} <music21.chord.Chord A2 A3>
#     {59.25} <music21.note.Note G>
#     {59.5} <music21.note.Note E>
#     {60.0} <music21.chord.Chord B2 D3 G#3>
#     {60.75} <music21.note.Rest rest>
#     {61.0} <music21.chord.Chord A2 C3 A3>
#     {61.5} <music21.chord.Chord A2 E3>
#     {62.0} <music21.chord.Chord E2 C3>
#     {62.5} <music21.chord.Chord A2 E3>
#     {63.0} <music21.chord.Chord E2 C3>
#     {63.5} <music21.chord.Chord C2 A2>
#     {64.0} <music21.note.Note B->
#     {64.75} <music21.note.Rest rest>
#     {65.0} <music21.note.Note A>
#     {65.25} <music21.note.Rest rest>
#     {66.0} <music21.chord.Chord G#2 G#3>
#     {66.75} <music21.note.Rest rest>
#     {67.0} <music21.chord.Chord A2 A3>
#     {67.25} <music21.note.Note G>
#     {67.5} <music21.note.Note E>
#     {68.0} <music21.chord.Chord B2 D3 G#3>
#     {68.75} <music21.note.Rest rest>
#     {69.0} <music21.chord.Chord A2 C3 A3>
#     {69.5} <music21.chord.Chord A2 E3>
#     {70.0} <music21.chord.Chord E2 C3>
#     {70.5} <music21.chord.Chord A2 E3>
#     {71.0} <music21.chord.Chord E2 C3>
#     {71.25} <music21.note.Note B>
#     {71.5} <music21.chord.Chord C2 A2>
#     {72.0} <music21.note.Note B>
#     {72.75} <music21.note.Rest rest>
#     {73.0} <music21.note.Note A>
#     {73.25} <music21.note.Rest rest>
#     {75.0} <music21.chord.Chord D3 G#3>
#     {75.3333} <music21.note.Note C>
#     {75.6667} <music21.note.Note B>
#     {76.0} <music21.note.Note A>
#     {78.75} <music21.note.Rest rest>
#     {79.0} <music21.note.Note C>
#     {79.3333} <music21.note.Note C>
#     {79.6667} <music21.note.Note C>
#     {80.0} <music21.note.Note B>
#     {80.75} <music21.note.Rest rest>
#     {81.0} <music21.note.Note A>
#     {81.25} <music21.note.Rest rest>
#     {82.0} <music21.chord.Chord E3 C4>
#     {82.5} <music21.chord.Chord C3 E3>
#     {83.0} <music21.chord.Chord G#2 D3>
#     {83.5} <music21.chord.Chord B2 D3 B3>
#     {84.0} <music21.chord.Chord A2 C3 A3>
#     {87.75} <music21.note.Rest rest>
#     {88.0} <music21.note.Note A>
#     {88.25} <music21.note.Rest rest>
#     {89.0} <music21.note.Note A>
#     {89.25} <music21.note.Rest rest>
#     {90.0} <music21.note.Note A>
#     {90.5} <music21.note.Note G#>
#     {91.0} <music21.note.Note A>
#     {91.25} <music21.note.Rest rest>
#     {91.5} <music21.note.Note C>
#     {91.75} <music21.note.Rest rest>
#     {92.0} <music21.note.Note A>
#     {92.25} <music21.note.Rest rest>
#     {93.0} <music21.note.Note A>
#     {93.25} <music21.note.Rest rest>
#     {94.0} <music21.note.Note A>
#     {94.5} <music21.note.Note G#>
#     {95.0} <music21.note.Note A>
#     {95.25} <music21.note.Rest rest>
#     {95.5} <music21.note.Note C>
#     {95.75} <music21.note.Rest rest>
#     {96.0} <music21.note.Note A>
#     {96.25} <music21.note.Rest rest>
#     {97.0} <music21.note.Note A>
#     {97.25} <music21.note.Rest rest>
#     {98.0} <music21.note.Note A>
#     {98.5} <music21.note.Note G#>
#     {99.0} <music21.note.Note A>
#     {99.25} <music21.note.Rest rest>
#     {99.5} <music21.note.Note C>
#     {99.75} <music21.note.Rest rest>
#     {100.0} <music21.note.Note A>
#     {100.25} <music21.note.Rest rest>
#     {101.0} <music21.note.Note A>
#     {101.25} <music21.note.Rest rest>
#     {102.0} <music21.note.Note A>
#     {102.5} <music21.note.Note G#>
#     {103.0} <music21.note.Note A>
#     {103.25} <music21.note.Rest rest>
#     {103.5} <music21.note.Note B>
#     {103.75} <music21.note.Rest rest>
#     {104.0} <music21.note.Note A>
#     {104.25} <music21.note.Rest rest>
#     {105.0} <music21.note.Note A>
#     {105.25} <music21.note.Rest rest>
#     {106.0} <music21.note.Note A>
#     {106.5} <music21.note.Note G#>
#     {107.0} <music21.note.Note A>
#     {107.25} <music21.note.Rest rest>
#     {107.5} <music21.note.Note C>
#     {107.75} <music21.note.Rest rest>
#     {108.0} <music21.note.Note B->
#     {108.25} <music21.note.Rest rest>
#     {109.0} <music21.note.Note B->
#     {109.25} <music21.note.Rest rest>
#     {110.0} <music21.note.Note B>
#     {110.5} <music21.note.Note E>
#     {111.0} <music21.note.Note G#>
#     {111.25} <music21.note.Rest rest>
#     {111.5} <music21.note.Note C>
#     {111.75} <music21.note.Rest rest>
#     {112.0} <music21.note.Note A>
#     {112.25} <music21.note.Rest rest>
#     {113.0} <music21.note.Note A>
#     {113.25} <music21.note.Rest rest>
#     {114.0} <music21.note.Note A>
#     {114.5} <music21.note.Note G#>
#     {115.0} <music21.note.Note A>
#     {115.25} <music21.note.Rest rest>
#     {115.5} <music21.note.Note C>
#     {115.75} <music21.note.Rest rest>
#     {116.0} <music21.note.Note A>
#     {116.25} <music21.note.Rest rest>
#     {117.0} <music21.note.Note A>
#     {117.25} <music21.note.Rest rest>
#     {118.0} <music21.note.Note A>
#     {118.5} <music21.note.Note G#>
#     {119.0} <music21.note.Note A>
#     {119.25} <music21.note.Rest rest>
#     {119.5} <music21.note.Note C>
#     {119.75} <music21.note.Rest rest>
#     {120.0} <music21.chord.Chord F2 F3>
#     {120.5} <music21.chord.Chord F2 F3>
#     {121.0} <music21.note.Rest rest>
#     {122.0} <music21.chord.Chord F2 F3>
#     {122.5} <music21.chord.Chord F2 F3>
#     {123.0} <music21.note.Rest rest>
#     {124.0} <music21.chord.Chord F2 F3>
#     {124.5} <music21.chord.Chord F2 F3>
#     {125.0} <music21.note.Rest rest>
#     {126.0} <music21.chord.Chord F2 F3>
#     {126.5} <music21.chord.Chord F2 F3>
#     {127.0} <music21.note.Rest rest>
#     {128.0} <music21.chord.Chord F2 F3>
#     {128.5} <music21.chord.Chord F2 F3>
#     {129.0} <music21.note.Rest rest>
#     {130.0} <music21.chord.Chord E2 E3>
#     {130.5} <music21.chord.Chord E2 E3>
#     {131.0} <music21.note.Rest rest>
#     {132.0} <music21.chord.Chord D2 D3>
#     {132.5} <music21.chord.Chord D2 D3>
#     {133.0} <music21.note.Rest rest>
#     {134.0} <music21.chord.Chord D2 D3>
#     {134.5} <music21.chord.Chord D2 D3>
#     {135.0} <music21.note.Rest rest>
#     {136.0} <music21.chord.Chord D2 D3>
#     {136.5} <music21.chord.Chord D2 D3>
#     {137.0} <music21.note.Rest rest>
#     {138.0} <music21.chord.Chord D2 D3>
#     {138.5} <music21.chord.Chord D2 D3>
#     {139.0} <music21.note.Rest rest>
#     {140.0} <music21.chord.Chord D2 D3>
#     {140.5} <music21.chord.Chord D2 D3>
#     {141.0} <music21.note.Rest rest>
#     {142.0} <music21.chord.Chord E2 E3>
#     {142.5} <music21.chord.Chord E2 E3>
#     {143.0} <music21.note.Rest rest>
#     {144.0} <music21.note.Note F>
#     {145.3333} <music21.note.Rest rest>
#     {145.5} <music21.note.Note E>
#     {146.0} <music21.note.Note D>
#     {146.75} <music21.note.Rest rest>
#     {147.0} <music21.note.Note D>
#     {147.5} <music21.note.Note D>
#     {148.0} <music21.note.Note C>
#     {148.75} <music21.note.Rest rest>
#     {149.0} <music21.note.Note C>
#     {149.75} <music21.note.Rest rest>
#     {150.0} <music21.note.Note B>
#     {150.6667} <music21.note.Note C>
#     {151.3333} <music21.note.Note D>
#     {152.0} <music21.note.Note C>
#     {154.75} <music21.note.Rest rest>
#     {155.0} <music21.note.Note E>
#     {155.5} <music21.note.Note E>
#     {156.0} <music21.note.Note A>
#     {157.75} <music21.note.Rest rest>
#     {158.0} <music21.note.Note E>
#     {159.75} <music21.note.Rest rest>
#     {160.0} <music21.note.Note A>
#     {160.75} <music21.note.Rest rest>
#     {162.0} <music21.note.Note A>
#     {162.75} <music21.note.Rest rest>
#     {164.0} <music21.note.Note A>
#     {164.75} <music21.note.Rest rest>
#     {165.0} <music21.note.Note A>
#     {165.75} <music21.note.Rest rest>
#     {166.0} <music21.note.Note A>
#     {166.75} <music21.note.Rest rest>
#     {167.0} <music21.note.Note G>
#     {167.75} <music21.note.Rest rest>
#     {168.0} <music21.note.Note A>
#     {168.75} <music21.note.Rest rest>
#     {170.0} <music21.note.Note A>
#     {170.75} <music21.note.Rest rest>
#     {172.0} <music21.note.Note A>
#     {172.75} <music21.note.Rest rest>
#     {173.0} <music21.note.Note A>
#     {173.75} <music21.note.Rest rest>
#     {174.0} <music21.note.Note A>
#     {174.75} <music21.note.Rest rest>
#     {175.0} <music21.note.Note A>
#     {175.75} <music21.note.Rest rest>
#     {176.0} <music21.note.Note A>
#     {176.75} <music21.note.Rest rest>
#     {177.0} <music21.note.Note E>
#     {177.3333} <music21.note.Note E>
#     {177.6667} <music21.note.Note E>
#     {178.0} <music21.note.Note A>
#     {178.75} <music21.note.Rest rest>
#     {179.0} <music21.note.Note E>
#     {179.3333} <music21.note.Note E>
#     {179.6667} <music21.note.Note E>
#     {180.0} <music21.note.Note A>
#     {180.75} <music21.note.Rest rest>
#     {181.0} <music21.note.Note E>
#     {181.3333} <music21.note.Note E>
#     {181.6667} <music21.note.Note E>
#     {182.0} <music21.note.Note G>
#     {182.5} <music21.note.Note G>
#     {182.6667} <music21.note.Note G>
#     {182.9167} <music21.note.Rest rest>
#     {183.0} <music21.note.Note D>
#     {183.3333} <music21.note.Note E>
#     {183.6667} <music21.note.Note C>
#     {184.0} <music21.note.Note A>
#     {184.75} <music21.note.Rest rest>
#     {185.0} <music21.note.Note E>
#     {185.3333} <music21.note.Note E>
#     {185.6667} <music21.note.Note E>
#     {186.0} <music21.note.Note A>
#     {186.75} <music21.note.Rest rest>
#     {187.0} <music21.note.Note G>
#     {187.3333} <music21.note.Note B>
#     {187.6667} <music21.note.Note G>
#     {188.0} <music21.note.Note A>
#     {188.75} <music21.note.Rest rest>
#     {189.0} <music21.note.Note F#>
#     {189.3333} <music21.note.Note G>
#     {189.6667} <music21.note.Note G#>
#     {190.0} <music21.note.Note A>
#     {190.75} <music21.note.Rest rest>
#     {191.0} <music21.note.Note A>
#     {191.3333} <music21.note.Note A>
#     {191.6667} <music21.note.Note A>
#     {192.0} <music21.note.Note B->
#     {192.75} <music21.note.Rest rest>
#     {193.0} <music21.note.Note A>
#     {193.25} <music21.note.Rest rest>
#     {194.0} <music21.chord.Chord G#2 G#3>
#     {194.75} <music21.note.Rest rest>
#     {195.0} <music21.chord.Chord A2 A3>
#     {195.25} <music21.note.Note G>
#     {195.5} <music21.note.Note E>
#     {196.0} <music21.chord.Chord B2 D3 G#3>
#     {196.75} <music21.note.Rest rest>
#     {197.0} <music21.chord.Chord A2 C3 A3>
#     {197.5} <music21.chord.Chord A2 E3>
#     {198.0} <music21.chord.Chord E2 C3>
#     {198.5} <music21.chord.Chord A2 E3>
#     {199.0} <music21.chord.Chord E2 C3>
#     {199.5} <music21.chord.Chord C2 A2>
#     {200.0} <music21.note.Note B->
#     {200.75} <music21.note.Rest rest>
#     {201.0} <music21.note.Note A>
#     {201.25} <music21.note.Rest rest>
#     {202.0} <music21.chord.Chord G#2 G#3>
#     {202.75} <music21.note.Rest rest>
#     {203.0} <music21.chord.Chord A2 A3>
#     {203.25} <music21.note.Note G>
#     {203.5} <music21.note.Note E>
#     {204.0} <music21.chord.Chord B2 D3 G#3>
#     {204.75} <music21.note.Rest rest>
#     {205.0} <music21.chord.Chord A2 C3 A3>
#     {205.5} <music21.chord.Chord A2 E3>
#     {206.0} <music21.chord.Chord E2 C3>
#     {206.5} <music21.chord.Chord A2 E3>
#     {207.0} <music21.chord.Chord E2 C3>
#     {207.25} <music21.note.Note B>
#     {207.5} <music21.chord.Chord C2 A2>
#     {208.0} <music21.note.Note B>
#     {208.75} <music21.note.Rest rest>
#     {209.0} <music21.note.Note A>
#     {209.25} <music21.note.Rest rest>
#     {211.0} <music21.chord.Chord D3 G#3>
#     {211.3333} <music21.note.Note C>
#     {211.6667} <music21.note.Note B>
#     {212.0} <music21.note.Note A>
#     {214.75} <music21.note.Rest rest>
#     {215.0} <music21.note.Note C>
#     {215.3333} <music21.note.Note C>
#     {215.6667} <music21.note.Note C>
#     {216.0} <music21.note.Note B>
#     {216.75} <music21.note.Rest rest>
#     {217.0} <music21.note.Note A>
#     {217.25} <music21.note.Rest rest>
#     {218.0} <music21.chord.Chord E3 C4>
#     {218.5} <music21.chord.Chord C3 E3>
#     {219.0} <music21.chord.Chord G#2 D3>
#     {219.5} <music21.chord.Chord B2 D3 B3>
#     {220.0} <music21.chord.Chord A2 C3 A3>
#     {223.75} <music21.note.Rest rest>
#     {224.0} <music21.note.Note A>
#     {224.25} <music21.note.Rest rest>
#     {225.0} <music21.note.Note A>
#     {225.25} <music21.note.Rest rest>
#     {226.0} <music21.note.Note A>
#     {226.5} <music21.note.Note G#>
#     {227.0} <music21.note.Note A>
#     {227.25} <music21.note.Rest rest>
#     {227.5} <music21.note.Note C>
#     {227.75} <music21.note.Rest rest>
#     {228.0} <music21.note.Note A>
#     {228.25} <music21.note.Rest rest>
#     {229.0} <music21.note.Note A>
#     {229.25} <music21.note.Rest rest>
#     {230.0} <music21.note.Note A>
#     {230.5} <music21.note.Note G#>
#     {231.0} <music21.note.Note A>
#     {231.25} <music21.note.Rest rest>
#     {231.5} <music21.note.Note C>
#     {231.75} <music21.note.Rest rest>
#     {232.0} <music21.note.Note A>
#     {232.25} <music21.note.Rest rest>
#     {233.0} <music21.note.Note A>
#     {233.25} <music21.note.Rest rest>
#     {234.0} <music21.note.Note A>
#     {234.5} <music21.note.Note G#>
#     {235.0} <music21.note.Note A>
#     {235.25} <music21.note.Rest rest>
#     {235.5} <music21.note.Note C>
#     {235.75} <music21.note.Rest rest>
#     {236.0} <music21.note.Note A>
#     {236.25} <music21.note.Rest rest>
#     {237.0} <music21.note.Note A>
#     {237.25} <music21.note.Rest rest>
#     {238.0} <music21.note.Note A>
#     {238.5} <music21.note.Note G#>
#     {239.0} <music21.note.Note A>
#     {239.25} <music21.note.Rest rest>
#     {239.5} <music21.note.Note B>
#     {239.75} <music21.note.Rest rest>
#     {240.0} <music21.note.Note A>
#     {240.25} <music21.note.Rest rest>
#     {241.0} <music21.note.Note A>
#     {241.25} <music21.note.Rest rest>
#     {242.0} <music21.note.Note A>
#     {242.5} <music21.note.Note G#>
#     {243.0} <music21.note.Note A>
#     {243.25} <music21.note.Rest rest>
#     {243.5} <music21.note.Note C>
#     {243.75} <music21.note.Rest rest>
#     {244.0} <music21.note.Note B->
#     {244.25} <music21.note.Rest rest>
#     {245.0} <music21.note.Note B->
#     {245.25} <music21.note.Rest rest>
#     {246.0} <music21.note.Note B>
#     {246.5} <music21.note.Note E>
#     {247.0} <music21.note.Note G#>
#     {247.25} <music21.note.Rest rest>
#     {247.5} <music21.note.Note C>
#     {247.75} <music21.note.Rest rest>
#     {248.0} <music21.note.Note A>
#     {248.25} <music21.note.Rest rest>
#     {249.0} <music21.note.Note A>
#     {249.25} <music21.note.Rest rest>
#     {250.0} <music21.note.Note A>
#     {250.5} <music21.note.Note G#>
#     {251.0} <music21.note.Note A>
#     {251.25} <music21.note.Rest rest>
#     {251.5} <music21.note.Note C>
#     {251.75} <music21.note.Rest rest>
#     {252.0} <music21.note.Note A>
#     {252.25} <music21.note.Rest rest>
#     {253.0} <music21.note.Note A>
#     {253.25} <music21.note.Rest rest>
#     {254.0} <music21.note.Note A>
#     {254.5} <music21.note.Note G#>
#     {255.0} <music21.note.Note A>
#     {255.25} <music21.note.Rest rest>
#     {255.5} <music21.note.Note C>
#     {255.75} <music21.note.Rest rest>
#     {256.0} <music21.chord.Chord F2 F3>
#     {256.5} <music21.chord.Chord F2 F3>
#     {257.0} <music21.note.Rest rest>
#     {258.0} <music21.chord.Chord F2 F3>
#     {258.5} <music21.chord.Chord F2 F3>
#     {259.0} <music21.note.Rest rest>
#     {260.0} <music21.chord.Chord F2 F3>
#     {260.5} <music21.chord.Chord F2 F3>
#     {261.0} <music21.note.Rest rest>
#     {262.0} <music21.chord.Chord F2 F3>
#     {262.5} <music21.chord.Chord F2 F3>
#     {263.0} <music21.note.Rest rest>
#     {264.0} <music21.chord.Chord F2 F3>
#     {264.5} <music21.chord.Chord F2 F3>
#     {265.0} <music21.note.Rest rest>
#     {266.0} <music21.chord.Chord E2 E3>
#     {266.5} <music21.chord.Chord E2 E3>
#     {267.0} <music21.note.Rest rest>
#     {268.0} <music21.chord.Chord D2 D3>
#     {268.5} <music21.chord.Chord D2 D3>
#     {269.0} <music21.note.Rest rest>
#     {270.0} <music21.chord.Chord D2 D3>
#     {270.5} <music21.chord.Chord D2 D3>
#     {271.0} <music21.note.Rest rest>
#     {272.0} <music21.chord.Chord D2 D3>
#     {272.5} <music21.chord.Chord D2 D3>
#     {273.0} <music21.note.Rest rest>
#     {274.0} <music21.chord.Chord D2 D3>
#     {274.5} <music21.chord.Chord D2 D3>
#     {275.0} <music21.note.Rest rest>
#     {276.0} <music21.chord.Chord D2 D3>
#     {276.5} <music21.chord.Chord D2 D3>
#     {277.0} <music21.note.Rest rest>
#     {278.0} <music21.chord.Chord E2 E3>
#     {278.5} <music21.chord.Chord E2 E3>
#     {279.0} <music21.note.Rest rest>
#     {280.0} <music21.note.Note F>
#     {281.3333} <music21.note.Rest rest>
#     {281.5} <music21.note.Note E>
#     {282.0} <music21.note.Note D>
#     {282.75} <music21.note.Rest rest>
#     {283.0} <music21.note.Note D>
#     {283.5} <music21.note.Note D>
#     {284.0} <music21.note.Note C>
#     {284.75} <music21.note.Rest rest>
#     {285.0} <music21.note.Note C>
#     {285.75} <music21.note.Rest rest>
#     {286.0} <music21.note.Note B>
#     {286.6667} <music21.note.Note C>
#     {287.3333} <music21.note.Note D>
#     {288.0} <music21.note.Note C>
#     {290.75} <music21.note.Rest rest>
#     {291.0} <music21.note.Note E>
#     {291.5} <music21.note.Note E>
#     {292.0} <music21.note.Note A>
#     {293.75} <music21.note.Rest rest>
#     {294.0} <music21.note.Note E>
#     {295.75} <music21.note.Rest rest>
#     {296.0} <music21.note.Note A>
#     {296.75} <music21.note.Rest rest>
#     {298.0} <music21.note.Note A>
#     {298.75} <music21.note.Rest rest>
#     {300.0} <music21.note.Note A>
#     {300.75} <music21.note.Rest rest>
#     {301.0} <music21.note.Note A>
#     {301.75} <music21.note.Rest rest>
#     {302.0} <music21.note.Note A>
#     {302.75} <music21.note.Rest rest>
#     {303.0} <music21.note.Note G>
#     {303.75} <music21.note.Rest rest>
#     {304.0} <music21.note.Note A>
#     {304.75} <music21.note.Rest rest>
#     {306.0} <music21.note.Note A>
#     {306.75} <music21.note.Rest rest>
#     {308.0} <music21.note.Note A>
#     {308.75} <music21.note.Rest rest>
#     {309.0} <music21.note.Note A>
#     {309.75} <music21.note.Rest rest>
#     {310.0} <music21.note.Note A>

# %%
elements_to_parse = midi.flat.notes # Returns an iterator

# %%
for e in elements_to_parse:
    print(e, e.offset)
    # Offset tells that at which moment the element will be played
# Out:
# <music21.chord.Chord C#4 E4 A4> 0.0
# <music21.note.Note A> 0.0
# <music21.note.Note A> 1.5
# <music21.note.Note A> 2.5
# <music21.note.Note A> 3.5
# <music21.note.Note A> 4.0
# <music21.note.Note A> 5.5
# <music21.note.Note A> 6.5
# <music21.note.Note A> 7.0
# <music21.chord.Chord D4 F4 B-4> 8.0
# <music21.note.Note A> 8.0
# <music21.note.Note A> 9.5
# <music21.note.Note A> 10.5
# <music21.note.Note A> 11.5
# <music21.note.Note A> 12.0
# <music21.note.Note A> 13.5
# <music21.note.Note A> 14.5
# <music21.note.Note A> 15.0
# <music21.chord.Chord E-4 F#4 B4> 16.0
# <music21.note.Note A> 16.0
# <music21.note.Note A> 17.5
# <music21.note.Note A> 18.5
# <music21.note.Note A> 19.5
# <music21.note.Note A> 20.0
# <music21.note.Note A> 21.5
# <music21.note.Note A> 22.5
# <music21.note.Note A> 23.0
# <music21.chord.Chord E4 G4 C5> 24.0
# <music21.note.Note A> 24.0
# <music21.note.Note A> 25.5
# <music21.note.Note A> 26.5
# <music21.note.Note A> 27.5
# <music21.note.Note A> 28.0
# <music21.note.Note A> 29.5
# <music21.note.Note A> 30.5
# <music21.note.Note A> 31.0
# <music21.chord.Chord C#4 E4 A4> 32.0
# <music21.chord.Chord A1 A2> 32.0
# <music21.chord.Chord A1 A2> 34.0
# <music21.chord.Chord A1 A2> 36.0
# <music21.chord.Chord A1 A2> 38.0
# <music21.chord.Chord C4 E4 A4> 39.0
# <music21.chord.Chord C4 E4 A4> 118/3
# <music21.chord.Chord C4 E4 A4> 119/3
# <music21.chord.Chord B3 D4 G4> 40.0
# <music21.note.Note A> 40.0
# <music21.note.Note E> 41.0
# <music21.note.Note E> 124/3
# <music21.note.Note E> 125/3
# <music21.chord.Chord D4 G4 B4> 42.0
# <music21.note.Note A> 42.0
# <music21.chord.Chord G4 B4 D5> 43.0
# <music21.note.Note E> 43.0
# <music21.note.Note E> 130/3
# <music21.note.Note E> 131/3
# <music21.chord.Chord B4 D5 G5> 44.0
# <music21.note.Note A> 44.0
# <music21.note.Note E> 45.0
# <music21.note.Note E> 136/3
# <music21.note.Note E> 137/3
# <music21.chord.Chord D5 G5 B5> 46.0
# <music21.note.Note G> 46.0
# <music21.note.Note G> 46.5
# <music21.note.Note G> 140/3
# <music21.chord.Chord B3 D4 G4> 47.0
# <music21.note.Note D> 47.0
# <music21.chord.Chord B3 D4 G4> 142/3
# <music21.note.Note E> 142/3
# <music21.chord.Chord B3 D4 G4> 143/3
# <music21.note.Note C> 143/3
# <music21.chord.Chord C4 E4 A4> 48.0
# <music21.note.Note A> 48.0
# <music21.note.Note E> 49.0
# <music21.note.Note E> 148/3
# <music21.note.Note E> 149/3
# <music21.chord.Chord A4 E5> 50.0
# <music21.note.Note A> 50.0
# <music21.note.Note G> 51.0
# <music21.note.Note B> 154/3
# <music21.note.Note G> 155/3
# <music21.chord.Chord E4 C5> 52.0
# <music21.note.Note A> 52.0
# <music21.note.Note F#> 53.0
# <music21.note.Note G> 160/3
# <music21.note.Note G#> 161/3
# <music21.chord.Chord C4 A4> 54.0
# <music21.note.Note A> 54.0
# <music21.chord.Chord C4 E4 A4> 55.0
# <music21.note.Note A> 55.0
# <music21.chord.Chord C4 E4 A4> 166/3
# <music21.note.Note A> 166/3
# <music21.chord.Chord C4 E4 A4> 167/3
# <music21.note.Note A> 167/3
# <music21.chord.Chord D4 F4 B-4> 56.0
# <music21.note.Note B-> 56.0
# <music21.chord.Chord C4 E4 A4> 57.0
# <music21.note.Note A> 57.0
# <music21.chord.Chord A3 E4> 57.5
# <music21.chord.Chord C4 E-4 G#4 C5> 58.0
# <music21.chord.Chord G#2 G#3> 58.0
# <music21.chord.Chord C4 E-4> 58.5
# <music21.chord.Chord C4 E4 A4> 59.0
# <music21.chord.Chord A2 A3> 59.0
# <music21.note.Note B> 59.25
# <music21.note.Note G> 59.25
# <music21.note.Note A> 59.5
# <music21.note.Note E> 59.5
# <music21.chord.Chord B3 D4 G#4> 60.0
# <music21.chord.Chord B2 D3 G#3> 60.0
# <music21.chord.Chord A3 C4 A4> 61.0
# <music21.chord.Chord A2 C3 A3> 61.0
# <music21.chord.Chord A2 E3> 61.5
# <music21.chord.Chord E2 C3> 62.0
# <music21.chord.Chord A2 E3> 62.5
# <music21.chord.Chord C4 E4 A4> 63.0
# <music21.chord.Chord E2 C3> 63.0
# <music21.chord.Chord C4 E4 A4> 190/3
# <music21.chord.Chord C2 A2> 63.5
# <music21.chord.Chord C4 E4 A4> 191/3
# <music21.chord.Chord D4 F4 B-4> 64.0
# <music21.note.Note B-> 64.0
# <music21.chord.Chord C4 E4 A4> 65.0
# <music21.note.Note A> 65.0
# <music21.chord.Chord A3 E4> 65.5
# <music21.chord.Chord C4 E-4 G#4 C5> 66.0
# <music21.chord.Chord G#2 G#3> 66.0
# <music21.chord.Chord C4 E-4> 66.5
# <music21.chord.Chord C4 E4 A4> 67.0
# <music21.chord.Chord A2 A3> 67.0
# <music21.note.Note B> 67.25
# <music21.note.Note G> 67.25
# <music21.note.Note A> 67.5
# <music21.note.Note E> 67.5
# <music21.chord.Chord B3 D4 G#4> 68.0
# <music21.chord.Chord B2 D3 G#3> 68.0
# <music21.chord.Chord A3 C4 A4> 69.0
# <music21.chord.Chord A2 C3 A3> 69.0
# <music21.chord.Chord A2 E3> 69.5
# <music21.chord.Chord E2 C3> 70.0
# <music21.chord.Chord A2 E3> 70.5
# <music21.chord.Chord A4 C5 E5> 71.0
# <music21.chord.Chord E2 C3> 71.0
# <music21.note.Note B> 71.25
# <music21.chord.Chord A4 C5 E5> 214/3
# <music21.chord.Chord C2 A2> 71.5
# <music21.chord.Chord A4 C5 E5> 215/3
# <music21.chord.Chord A4 B4 E-5> 72.0
# <music21.note.Note B> 72.0
# <music21.chord.Chord A4 C5 E5> 73.0
# <music21.note.Note A> 73.0
# <music21.chord.Chord E4 C5> 74.0
# <music21.chord.Chord C4 E4> 74.5
# <music21.chord.Chord D4 E4 G#4> 75.0
# <music21.chord.Chord D3 G#3> 75.0
# <music21.chord.Chord D4 E4 G#4> 226/3
# <music21.note.Note C> 226/3
# <music21.chord.Chord D4 E4 G#4> 227/3
# <music21.note.Note B> 227/3
# <music21.chord.Chord C4 E4 A4> 76.0
# <music21.note.Note A> 76.0
# <music21.chord.Chord A4 C5 E5> 79.0
# <music21.note.Note C> 79.0
# <music21.chord.Chord A4 C5 E5> 238/3
# <music21.note.Note C> 238/3
# <music21.chord.Chord A4 C5 E5> 239/3
# <music21.note.Note C> 239/3
# <music21.chord.Chord A4 B4 E-5> 80.0
# <music21.note.Note B> 80.0
# <music21.chord.Chord A4 C5 E5> 81.0
# <music21.note.Note A> 81.0
# <music21.chord.Chord E3 C4> 82.0
# <music21.chord.Chord C3 E3> 82.5
# <music21.chord.Chord D4 E4 G#4> 83.0
# <music21.chord.Chord G#2 D3> 83.0
# <music21.chord.Chord D4 E4 G#4> 250/3
# <music21.chord.Chord B2 D3 B3> 83.5
# <music21.chord.Chord D4 E4 G#4> 251/3
# <music21.chord.Chord C4 E4 A4> 84.0
# <music21.chord.Chord A2 C3 A3> 84.0
# <music21.chord.Chord C4 E4 A4> 88.0
# <music21.note.Note A> 88.0
# <music21.chord.Chord D4 G#4 B4> 89.0
# <music21.note.Note A> 89.0
# <music21.chord.Chord E4 A4 C5> 89.5
# <music21.chord.Chord F4 B4 D5> 90.0
# <music21.note.Note A> 90.0
# <music21.note.Note G#> 90.5
# <music21.chord.Chord E4 A4 C5> 91.0
# <music21.note.Note A> 91.0
# <music21.chord.Chord D4 G#4 B4> 91.5
# <music21.note.Note C> 91.5
# <music21.chord.Chord E4 A4 C5> 92.0
# <music21.note.Note A> 92.0
# <music21.chord.Chord C4 E4 A4> 93.0
# <music21.note.Note A> 93.0
# <music21.note.Note A> 94.0
# <music21.note.Note G#> 94.5
# <music21.note.Note A> 95.0
# <music21.note.Note C> 95.5
# <music21.note.Note A> 96.0
# <music21.note.Note A> 97.0
# <music21.note.Note A> 98.0
# <music21.note.Note G#> 98.5
# <music21.chord.Chord E4 A4 C5> 99.0
# <music21.note.Note A> 99.0
# <music21.chord.Chord E4 B4 D5> 298/3
# <music21.note.Note C> 99.5
# <music21.chord.Chord E4 C5 E5> 299/3
# <music21.chord.Chord G#4 D5 F5> 100.0
# <music21.note.Note A> 100.0
# <music21.chord.Chord D6 G#6 D7> 101.0
# <music21.note.Note A> 101.0
# <music21.chord.Chord D6 G#6 D7> 304/3
# <music21.chord.Chord D6 G#6 D7> 305/3
# <music21.chord.Chord D6 G#6 D7> 102.0
# <music21.note.Note A> 102.0
# <music21.note.Note G#> 102.5
# <music21.chord.Chord E4 G#4 B4> 103.0
# <music21.note.Note A> 103.0
# <music21.chord.Chord E4 A4 C5> 310/3
# <music21.note.Note B> 103.5
# <music21.chord.Chord G#4 B4 D5> 311/3
# <music21.chord.Chord A4 C5 E5> 104.0
# <music21.note.Note A> 104.0
# <music21.chord.Chord C6 A6 C7> 105.0
# <music21.note.Note A> 105.0
# <music21.chord.Chord C6 A6 C7> 316/3
# <music21.chord.Chord C6 A6 C7> 317/3
# <music21.chord.Chord C6 A6 C7> 106.0
# <music21.note.Note A> 106.0
# <music21.chord.Chord C4 E4 A4> 106.5
# <music21.note.Note G#> 106.5
# <music21.chord.Chord D4 G#4 B4> 107.0
# <music21.note.Note A> 107.0
# <music21.chord.Chord E4 A4 C5> 107.5
# <music21.note.Note C> 107.5
# <music21.note.Note D> 108.0
# <music21.chord.Chord A4 D5> 108.0
# <music21.note.Note B-> 108.0
# <music21.note.Note F> 109.0
# <music21.note.Note C> 109.0
# <music21.note.Note B-> 109.0
# <music21.note.Note B-> 109.5
# <music21.chord.Chord B3 D4> 110.0
# <music21.note.Note G#> 110.0
# <music21.note.Note B> 110.0
# <music21.note.Note E> 110.5
# <music21.note.Note E> 110.5
# <music21.chord.Chord D4 G#4 C5> 111.0
# <music21.note.Note G#> 111.0
# <music21.note.Note C> 111.5
# <music21.chord.Chord C4 E4 A4> 112.0
# <music21.note.Note A> 112.0
# <music21.note.Note A> 113.0
# <music21.note.Note A> 114.0
# <music21.note.Note G#> 114.5
# <music21.note.Note A> 115.0
# <music21.note.Note C> 115.5
# <music21.note.Note A> 116.0
# <music21.note.Note A> 117.0
# <music21.note.Note A> 118.0
# <music21.note.Note G#> 118.5
# <music21.note.Note A> 119.0
# <music21.note.Note C> 119.5
# <music21.chord.Chord F5 A5> 120.0
# <music21.chord.Chord F2 F3> 120.0
# <music21.chord.Chord F2 F3> 120.5
# <music21.chord.Chord E5 G5> 121.0
# <music21.note.Note B> 121.0
# <music21.note.Note C> 121.5
# <music21.chord.Chord D5 F5 D6> 122.0
# <music21.chord.Chord F2 F3> 122.0
# <music21.chord.Chord F2 F3> 122.5
# <music21.chord.Chord E5 G5> 123.0
# <music21.note.Note C> 123.0
# <music21.note.Note B> 123.5
# <music21.note.Note F> 124.0
# <music21.chord.Chord A5 C6> 124.0
# <music21.chord.Chord F2 F3> 124.0
# <music21.chord.Chord F2 F3> 124.5
# <music21.note.Note A> 125.0
# <music21.chord.Chord F2 F3> 126.0
# <music21.chord.Chord F2 F3> 126.5
# <music21.chord.Chord F2 F3> 128.0
# <music21.chord.Chord F2 F3> 128.5
# <music21.note.Note E> 130.0
# <music21.chord.Chord E2 E3> 130.0
# <music21.chord.Chord E2 E3> 130.5
# <music21.chord.Chord F4 A4> 132.0
# <music21.chord.Chord D2 D3> 132.0
# <music21.chord.Chord D2 D3> 132.5
# <music21.chord.Chord G4 B4> 133.0
# <music21.chord.Chord A4 C5> 133.5
# <music21.chord.Chord B4 D5> 134.0
# <music21.chord.Chord D2 D3> 134.0
# <music21.chord.Chord D2 D3> 134.5
# <music21.chord.Chord A4 C5> 135.0
# <music21.chord.Chord G4 B4> 135.5
# <music21.chord.Chord A4 C5> 136.0
# <music21.chord.Chord D2 D3> 136.0
# <music21.chord.Chord D2 D3> 136.5
# <music21.chord.Chord F4 A4> 137.0
# <music21.chord.Chord D2 D3> 138.0
# <music21.chord.Chord D2 D3> 138.5
# <music21.chord.Chord D2 D3> 140.0
# <music21.chord.Chord D2 D3> 140.5
# <music21.chord.Chord E2 E3> 142.0
# <music21.chord.Chord E2 E3> 142.5
# <music21.note.Note F> 144.0
# <music21.chord.Chord A4 C5> 144.0
# <music21.note.Note F> 144.0
# <music21.chord.Chord A4 D5> 145.0
# <music21.chord.Chord A4 E5> 145.5
# <music21.note.Note E> 145.5
# <music21.chord.Chord G#4 F5> 146.0
# <music21.note.Note D> 146.0
# <music21.chord.Chord G#4 E5> 147.0
# <music21.note.Note D> 147.0
# <music21.chord.Chord G#4 D5> 147.5
# <music21.note.Note D> 147.5
# <music21.chord.Chord E4 G4 E5> 148.0
# <music21.note.Note C> 148.0
# <music21.chord.Chord F4 C5 F5> 149.0
# <music21.note.Note C> 149.0
# <music21.chord.Chord G4 C5 G5> 149.5
# <music21.chord.Chord G#4 B4 F5 G#5> 150.0
# <music21.note.Note B> 150.0
# <music21.note.Note C> 452/3
# <music21.chord.Chord G4 D5> 151.0
# <music21.note.Note D> 454/3
# <music21.chord.Chord G#4 D5 F5> 151.5
# <music21.chord.Chord G4 C5 E5> 152.0
# <music21.note.Note C> 152.0
# <music21.chord.Chord G#4 B4 D5> 155.0
# <music21.note.Note E> 155.0
# <music21.chord.Chord C5 E5> 466/3
# <music21.note.Note E> 155.5
# <music21.chord.Chord D5 F5> 467/3
# <music21.chord.Chord A4 C5 E5> 156.0
# <music21.note.Note A> 156.0
# <music21.chord.Chord G#4 D5> 158.0
# <music21.note.Note E> 158.0
# <music21.note.Note C> 158.5
# <music21.chord.Chord D4 B4> 159.0
# <music21.note.Note E> 159.5
# <music21.chord.Chord C4 E4 A4> 160.0
# <music21.note.Note A> 160.0
# <music21.note.Note A> 162.0
# <music21.note.Note A> 164.0
# <music21.note.Note A> 165.0
# <music21.note.Note A> 166.0
# <music21.chord.Chord B3 D4 G4> 167.0
# <music21.note.Note G> 167.0
# <music21.chord.Chord C4 A4> 502/3
# <music21.chord.Chord D4 B4> 503/3
# <music21.chord.Chord C4 E4 A4> 168.0
# <music21.note.Note A> 168.0
# <music21.note.Note A> 170.0
# <music21.note.Note A> 172.0
# <music21.note.Note A> 173.0
# <music21.note.Note A> 174.0
# <music21.chord.Chord C4 E4 A4> 175.0
# <music21.note.Note A> 175.0
# <music21.chord.Chord C4 E4 A4> 526/3
# <music21.chord.Chord C4 E4 A4> 527/3
# <music21.chord.Chord B3 D4 G4> 176.0
# <music21.note.Note A> 176.0
# <music21.note.Note E> 177.0
# <music21.note.Note E> 532/3
# <music21.note.Note E> 533/3
# <music21.chord.Chord D4 G4 B4> 178.0
# <music21.note.Note A> 178.0
# <music21.chord.Chord G4 B4 D5> 179.0
# <music21.note.Note E> 179.0
# <music21.note.Note E> 538/3
# <music21.note.Note E> 539/3
# <music21.chord.Chord B4 D5 G5> 180.0
# <music21.note.Note A> 180.0
# <music21.note.Note E> 181.0
# <music21.note.Note E> 544/3
# <music21.note.Note E> 545/3
# <music21.chord.Chord D5 G5 B5> 182.0
# <music21.note.Note G> 182.0
# <music21.note.Note G> 182.5
# <music21.note.Note G> 548/3
# <music21.chord.Chord B3 D4 G4> 183.0
# <music21.note.Note D> 183.0
# <music21.chord.Chord B3 D4 G4> 550/3
# <music21.note.Note E> 550/3
# <music21.chord.Chord B3 D4 G4> 551/3
# <music21.note.Note C> 551/3
# <music21.chord.Chord C4 E4 A4> 184.0
# <music21.note.Note A> 184.0
# <music21.note.Note E> 185.0
# <music21.note.Note E> 556/3
# <music21.note.Note E> 557/3
# <music21.chord.Chord A4 E5> 186.0
# <music21.note.Note A> 186.0
# <music21.note.Note G> 187.0
# <music21.note.Note B> 562/3
# <music21.note.Note G> 563/3
# <music21.chord.Chord E4 C5> 188.0
# <music21.note.Note A> 188.0
# <music21.note.Note F#> 189.0
# <music21.note.Note G> 568/3
# <music21.note.Note G#> 569/3
# <music21.chord.Chord C4 A4> 190.0
# <music21.note.Note A> 190.0
# <music21.chord.Chord C4 E4 A4> 191.0
# <music21.note.Note A> 191.0
# <music21.chord.Chord C4 E4 A4> 574/3
# <music21.note.Note A> 574/3
# <music21.chord.Chord C4 E4 A4> 575/3
# <music21.note.Note A> 575/3
# <music21.chord.Chord D4 F4 B-4> 192.0
# <music21.note.Note B-> 192.0
# <music21.chord.Chord C4 E4 A4> 193.0
# <music21.note.Note A> 193.0
# <music21.chord.Chord A3 E4> 193.5
# <music21.chord.Chord C4 E-4 G#4 C5> 194.0
# <music21.chord.Chord G#2 G#3> 194.0
# <music21.chord.Chord C4 E-4> 194.5
# <music21.chord.Chord C4 E4 A4> 195.0
# <music21.chord.Chord A2 A3> 195.0
# <music21.note.Note B> 195.25
# <music21.note.Note G> 195.25
# <music21.note.Note A> 195.5
# <music21.note.Note E> 195.5
# <music21.chord.Chord B3 D4 G#4> 196.0
# <music21.chord.Chord B2 D3 G#3> 196.0
# <music21.chord.Chord A3 C4 A4> 197.0
# <music21.chord.Chord A2 C3 A3> 197.0
# <music21.chord.Chord A2 E3> 197.5
# <music21.chord.Chord E2 C3> 198.0
# <music21.chord.Chord A2 E3> 198.5
# <music21.chord.Chord C4 E4 A4> 199.0
# <music21.chord.Chord E2 C3> 199.0
# <music21.chord.Chord C4 E4 A4> 598/3
# <music21.chord.Chord C2 A2> 199.5
# <music21.chord.Chord C4 E4 A4> 599/3
# <music21.chord.Chord D4 F4 B-4> 200.0
# <music21.note.Note B-> 200.0
# <music21.chord.Chord C4 E4 A4> 201.0
# <music21.note.Note A> 201.0
# <music21.chord.Chord A3 E4> 201.5
# <music21.chord.Chord C4 E-4 G#4 C5> 202.0
# <music21.chord.Chord G#2 G#3> 202.0
# <music21.chord.Chord C4 E-4> 202.5
# <music21.chord.Chord C4 E4 A4> 203.0
# <music21.chord.Chord A2 A3> 203.0
# <music21.note.Note B> 203.25
# <music21.note.Note G> 203.25
# <music21.note.Note A> 203.5
# <music21.note.Note E> 203.5
# <music21.chord.Chord B3 D4 G#4> 204.0
# <music21.chord.Chord B2 D3 G#3> 204.0
# <music21.chord.Chord A3 C4 A4> 205.0
# <music21.chord.Chord A2 C3 A3> 205.0
# <music21.chord.Chord A2 E3> 205.5
# <music21.chord.Chord E2 C3> 206.0
# <music21.chord.Chord A2 E3> 206.5
# <music21.chord.Chord A4 C5 E5> 207.0
# <music21.chord.Chord E2 C3> 207.0
# <music21.note.Note B> 207.25
# <music21.chord.Chord A4 C5 E5> 622/3
# <music21.chord.Chord C2 A2> 207.5
# <music21.chord.Chord A4 C5 E5> 623/3
# <music21.chord.Chord A4 B4 E-5> 208.0
# <music21.note.Note B> 208.0
# <music21.chord.Chord A4 C5 E5> 209.0
# <music21.note.Note A> 209.0
# <music21.chord.Chord E4 C5> 210.0
# <music21.chord.Chord C4 E4> 210.5
# <music21.chord.Chord D4 E4 G#4> 211.0
# <music21.chord.Chord D3 G#3> 211.0
# <music21.chord.Chord D4 E4 G#4> 634/3
# <music21.note.Note C> 634/3
# <music21.chord.Chord D4 E4 G#4> 635/3
# <music21.note.Note B> 635/3
# <music21.chord.Chord C4 E4 A4> 212.0
# <music21.note.Note A> 212.0
# <music21.chord.Chord A4 C5 E5> 215.0
# <music21.note.Note C> 215.0
# <music21.chord.Chord A4 C5 E5> 646/3
# <music21.note.Note C> 646/3
# <music21.chord.Chord A4 C5 E5> 647/3
# <music21.note.Note C> 647/3
# <music21.chord.Chord A4 B4 E-5> 216.0
# <music21.note.Note B> 216.0
# <music21.chord.Chord A4 C5 E5> 217.0
# <music21.note.Note A> 217.0
# <music21.chord.Chord E3 C4> 218.0
# <music21.chord.Chord C3 E3> 218.5
# <music21.chord.Chord D4 E4 G#4> 219.0
# <music21.chord.Chord G#2 D3> 219.0
# <music21.chord.Chord D4 E4 G#4> 658/3
# <music21.chord.Chord B2 D3 B3> 219.5
# <music21.chord.Chord D4 E4 G#4> 659/3
# <music21.chord.Chord C4 E4 A4> 220.0
# <music21.chord.Chord A2 C3 A3> 220.0
# <music21.chord.Chord C4 E4 A4> 224.0
# <music21.note.Note A> 224.0
# <music21.chord.Chord D4 G#4 B4> 225.0
# <music21.note.Note A> 225.0
# <music21.chord.Chord E4 A4 C5> 225.5
# <music21.chord.Chord F4 B4 D5> 226.0
# <music21.note.Note A> 226.0
# <music21.note.Note G#> 226.5
# <music21.chord.Chord E4 A4 C5> 227.0
# <music21.note.Note A> 227.0
# <music21.chord.Chord D4 G#4 B4> 227.5
# <music21.note.Note C> 227.5
# <music21.chord.Chord E4 A4 C5> 228.0
# <music21.note.Note A> 228.0
# <music21.chord.Chord C4 E4 A4> 229.0
# <music21.note.Note A> 229.0
# <music21.note.Note A> 230.0
# <music21.note.Note G#> 230.5
# <music21.note.Note A> 231.0
# <music21.note.Note C> 231.5
# <music21.note.Note A> 232.0
# <music21.note.Note A> 233.0
# <music21.note.Note A> 234.0
# <music21.note.Note G#> 234.5
# <music21.chord.Chord E4 A4 C5> 235.0
# <music21.note.Note A> 235.0
# <music21.chord.Chord E4 B4 D5> 706/3
# <music21.note.Note C> 235.5
# <music21.chord.Chord E4 C5 E5> 707/3
# <music21.chord.Chord G#4 D5 F5> 236.0
# <music21.note.Note A> 236.0
# <music21.chord.Chord D6 G#6 D7> 237.0
# <music21.note.Note A> 237.0
# <music21.chord.Chord D6 G#6 D7> 712/3
# <music21.chord.Chord D6 G#6 D7> 713/3
# <music21.chord.Chord D6 G#6 D7> 238.0
# <music21.note.Note A> 238.0
# <music21.note.Note G#> 238.5
# <music21.chord.Chord E4 G#4 B4> 239.0
# <music21.note.Note A> 239.0
# <music21.chord.Chord E4 A4 C5> 718/3
# <music21.note.Note B> 239.5
# <music21.chord.Chord G#4 B4 D5> 719/3
# <music21.chord.Chord A4 C5 E5> 240.0
# <music21.note.Note A> 240.0
# <music21.chord.Chord C6 A6 C7> 241.0
# <music21.note.Note A> 241.0
# <music21.chord.Chord C6 A6 C7> 724/3
# <music21.chord.Chord C6 A6 C7> 725/3
# <music21.chord.Chord C6 A6 C7> 242.0
# <music21.note.Note A> 242.0
# <music21.chord.Chord C4 E4 A4> 242.5
# <music21.note.Note G#> 242.5
# <music21.chord.Chord D4 G#4 B4> 243.0
# <music21.note.Note A> 243.0
# <music21.chord.Chord E4 A4 C5> 243.5
# <music21.note.Note C> 243.5
# <music21.note.Note D> 244.0
# <music21.chord.Chord A4 D5> 244.0
# <music21.note.Note B-> 244.0
# <music21.note.Note F> 245.0
# <music21.note.Note C> 245.0
# <music21.note.Note B-> 245.0
# <music21.note.Note B-> 245.5
# <music21.chord.Chord B3 D4> 246.0
# <music21.note.Note G#> 246.0
# <music21.note.Note B> 246.0
# <music21.note.Note E> 246.5
# <music21.note.Note E> 246.5
# <music21.chord.Chord D4 G#4 C5> 247.0
# <music21.note.Note G#> 247.0
# <music21.note.Note C> 247.5
# <music21.chord.Chord C4 E4 A4> 248.0
# <music21.note.Note A> 248.0
# <music21.note.Note A> 249.0
# <music21.note.Note A> 250.0
# <music21.note.Note G#> 250.5
# <music21.note.Note A> 251.0
# <music21.note.Note C> 251.5
# <music21.note.Note A> 252.0
# <music21.note.Note A> 253.0
# <music21.note.Note A> 254.0
# <music21.note.Note G#> 254.5
# <music21.note.Note A> 255.0
# <music21.note.Note C> 255.5
# <music21.chord.Chord F5 A5> 256.0
# <music21.chord.Chord F2 F3> 256.0
# <music21.chord.Chord F2 F3> 256.5
# <music21.chord.Chord E5 G5> 257.0
# <music21.note.Note B> 257.0
# <music21.note.Note C> 257.5
# <music21.chord.Chord D5 F5 D6> 258.0
# <music21.chord.Chord F2 F3> 258.0
# <music21.chord.Chord F2 F3> 258.5
# <music21.chord.Chord E5 G5> 259.0
# <music21.note.Note C> 259.0
# <music21.note.Note B> 259.5
# <music21.note.Note F> 260.0
# <music21.chord.Chord A5 C6> 260.0
# <music21.chord.Chord F2 F3> 260.0
# <music21.chord.Chord F2 F3> 260.5
# <music21.note.Note A> 261.0
# <music21.chord.Chord F2 F3> 262.0
# <music21.chord.Chord F2 F3> 262.5
# <music21.chord.Chord F2 F3> 264.0
# <music21.chord.Chord F2 F3> 264.5
# <music21.note.Note E> 266.0
# <music21.chord.Chord E2 E3> 266.0
# <music21.chord.Chord E2 E3> 266.5
# <music21.chord.Chord F4 A4> 268.0
# <music21.chord.Chord D2 D3> 268.0
# <music21.chord.Chord D2 D3> 268.5
# <music21.chord.Chord G4 B4> 269.0
# <music21.chord.Chord A4 C5> 269.5
# <music21.chord.Chord B4 D5> 270.0
# <music21.chord.Chord D2 D3> 270.0
# <music21.chord.Chord D2 D3> 270.5
# <music21.chord.Chord A4 C5> 271.0
# <music21.chord.Chord G4 B4> 271.5
# <music21.chord.Chord A4 C5> 272.0
# <music21.chord.Chord D2 D3> 272.0
# <music21.chord.Chord D2 D3> 272.5
# <music21.chord.Chord F4 A4> 273.0
# <music21.chord.Chord D2 D3> 274.0
# <music21.chord.Chord D2 D3> 274.5
# <music21.chord.Chord D2 D3> 276.0
# <music21.chord.Chord D2 D3> 276.5
# <music21.chord.Chord E2 E3> 278.0
# <music21.chord.Chord E2 E3> 278.5
# <music21.note.Note F> 280.0
# <music21.chord.Chord A4 C5> 280.0
# <music21.note.Note F> 280.0
# <music21.chord.Chord A4 D5> 281.0
# <music21.chord.Chord A4 E5> 281.5
# <music21.note.Note E> 281.5
# <music21.chord.Chord G#4 F5> 282.0
# <music21.note.Note D> 282.0
# <music21.chord.Chord G#4 E5> 283.0
# <music21.note.Note D> 283.0
# <music21.chord.Chord G#4 D5> 283.5
# <music21.note.Note D> 283.5
# <music21.chord.Chord E4 G4 E5> 284.0
# <music21.note.Note C> 284.0
# <music21.chord.Chord F4 C5 F5> 285.0
# <music21.note.Note C> 285.0
# <music21.chord.Chord G4 C5 G5> 285.5
# <music21.chord.Chord G#4 B4 F5 G#5> 286.0
# <music21.note.Note B> 286.0
# <music21.note.Note C> 860/3
# <music21.chord.Chord G4 D5> 287.0
# <music21.note.Note D> 862/3
# <music21.chord.Chord G#4 D5 F5> 287.5
# <music21.chord.Chord G4 C5 E5> 288.0
# <music21.note.Note C> 288.0
# <music21.chord.Chord G#4 B4 D5> 291.0
# <music21.note.Note E> 291.0
# <music21.chord.Chord C5 E5> 874/3
# <music21.note.Note E> 291.5
# <music21.chord.Chord D5 F5> 875/3
# <music21.chord.Chord A4 C5 E5> 292.0
# <music21.note.Note A> 292.0
# <music21.chord.Chord G#4 D5> 294.0
# <music21.note.Note E> 294.0
# <music21.note.Note C> 294.5
# <music21.chord.Chord D4 B4> 295.0
# <music21.note.Note E> 295.5
# <music21.chord.Chord C4 E4 A4> 296.0
# <music21.note.Note A> 296.0
# <music21.note.Note A> 298.0
# <music21.note.Note A> 300.0
# <music21.note.Note A> 301.0
# <music21.note.Note A> 302.0
# <music21.chord.Chord B3 D4 G4> 303.0
# <music21.note.Note G> 303.0
# <music21.chord.Chord C4 A4> 910/3
# <music21.chord.Chord D4 B4> 911/3
# <music21.chord.Chord C4 E4 A4> 304.0
# <music21.note.Note A> 304.0
# <music21.note.Note A> 306.0
# <music21.note.Note A> 308.0
# <music21.note.Note A> 309.0
# <music21.note.Note A> 310.0

# %%
# Note
print(isinstance(elements_to_parse[3],note.Note))
print(isinstance(elements_to_parse[3],chord.Chord))
print(str(elements_to_parse[3].pitch))
# Out:
# True
# False
# A2

# %%
# Chord
print(isinstance(elements_to_parse[91],note.Note))
print(isinstance(elements_to_parse[91],chord.Chord))
print(elements_to_parse[91].normalOrder)
print("+".join(str(n) for n in elements_to_parse[91].normalOrder))
# Out:
# False
# True
# [9, 0, 4]
# 9+0+4

# %%
notes_demo = []

for ele in elements_to_parse:
    # if ele is a Note, then store its pitch
    if isinstance(ele,note.Note):
        notes_demo.append(str(ele.pitch))
    
    # if ele is a Chord, then split each node of chord and join them with +
    elif isinstance(ele,chord.Chord):
        notes_demo.append("+".join(str(n) for n in ele.normalOrder))

# %%
len(notes_demo)
# Out:
# 682

# %% [markdown]
# ### Preprocessing all files

# %%
notes = []

for file in glob.glob("piano_tunes/*.mid"):
    midi = converter.parse(file) # Converts file into stream.Score object
    
    print("Parsing %s"%file)
    
    elements_to_parse = midi.flat.notes
    
    for ele in elements_to_parse:
        # if ele is a Note, then store its pitch
        if isinstance(ele,note.Note):
            notes.append(str(ele.pitch))

        # if ele is a Chord, then split each node of chord and join them with +
        elif isinstance(ele,chord.Chord):
            notes.append("+".join(str(n) for n in ele.normalOrder))
# Out:
# Parsing piano_tunes\0fithos.mid
# Parsing piano_tunes\8.mid
# Parsing piano_tunes\ahead_on_our_way_piano.mid
# Parsing piano_tunes\AT.mid
# Parsing piano_tunes\balamb.mid
# Parsing piano_tunes\bcm.mid
# Parsing piano_tunes\BlueStone_LastDungeon.mid
# Parsing piano_tunes\braska.mid
# Parsing piano_tunes\caitsith.mid
# Parsing piano_tunes\Cids.mid
# Parsing piano_tunes\cosmo.mid
# Parsing piano_tunes\costadsol.mid
# Parsing piano_tunes\dayafter.mid
# Parsing piano_tunes\decisive.mid
# Parsing piano_tunes\dontbeafraid.mid
# Parsing piano_tunes\DOS.mid
# Parsing piano_tunes\electric_de_chocobo.mid
# Parsing piano_tunes\Eternal_Harvest.mid
# Parsing piano_tunes\EyesOnMePiano.mid
# Parsing piano_tunes\ff11_awakening_piano.mid
# Parsing piano_tunes\ff1battp.mid
# Parsing piano_tunes\FF3_Battle_(Piano).mid
# Parsing piano_tunes\FF3_Third_Phase_Final_(Piano).mid
# Parsing piano_tunes\ff4-airship.mid
# Parsing piano_tunes\Ff4-BattleLust.mid
# Parsing piano_tunes\ff4-fight1.mid
# Parsing piano_tunes\ff4-town.mid
# Parsing piano_tunes\FF4.mid
# Parsing piano_tunes\ff4pclov.mid
# Parsing piano_tunes\ff4_piano_collections-main_theme.mid
# Parsing piano_tunes\FF6epitaph_piano.mid
# Parsing piano_tunes\ff6shap.mid
# Parsing piano_tunes\Ff7-Cinco.mid
# Parsing piano_tunes\Ff7-Jenova_Absolute.mid
# Parsing piano_tunes\ff7-mainmidi.mid
# Parsing piano_tunes\Ff7-One_Winged.mid
# Parsing piano_tunes\ff7themep.mid
# Parsing piano_tunes\ff8-lfp.mid
# Parsing piano_tunes\FF8_Shuffle_or_boogie_pc.mid
# Parsing piano_tunes\FFIII_Edgar_And_Sabin_Piano.mid
# Parsing piano_tunes\FFIXQuMarshP.mid
# Parsing piano_tunes\FFIX_Piano.mid
# Parsing piano_tunes\FFVII_BATTLE.mid
# Parsing piano_tunes\FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing piano_tunes\Fiend_Battle_(Piano).mid
# Parsing piano_tunes\Fierce_Battle_(Piano).mid
# Parsing piano_tunes\figaro.mid
# Parsing piano_tunes\Finalfantasy5gilgameshp.mid
# Parsing piano_tunes\Finalfantasy6fanfarecomplete.mid
# Parsing piano_tunes\Final_Fantasy_7_-_Judgement_Day_Piano.mid
# Parsing piano_tunes\Final_Fantasy_Matouyas_Cave_Piano.mid
# Parsing piano_tunes\fortresscondor.mid
# Parsing piano_tunes\Fyw_piano.mid
# Parsing piano_tunes\gerudo.mid
# Parsing piano_tunes\goldsaucer.mid
# Parsing piano_tunes\Gold_Silver_Rival_Battle.mid
# Parsing piano_tunes\great_war.mid
# Parsing piano_tunes\HighwindTakestotheSkies.mid
# Parsing piano_tunes\In_Zanarkand.mid
# Parsing piano_tunes\JENOVA.mid
# Parsing piano_tunes\Kingdom_Hearts_Dearly_Beloved.mid
# Parsing piano_tunes\Kingdom_Hearts_Traverse_Town.mid
# Parsing piano_tunes\Life_Stream.mid
# Parsing piano_tunes\lurk_in_dark.mid
# Parsing piano_tunes\mining.mid
# Parsing piano_tunes\Oppressed.mid
# Parsing piano_tunes\OTD5YA.mid
# Parsing piano_tunes\path_of_repentance.mid
# Parsing piano_tunes\pkelite4.mid
# Parsing piano_tunes\Rachel_Piano_tempofix.mid
# Parsing piano_tunes\redwings.mid
# Parsing piano_tunes\relmstheme-piano.mid
# Parsing piano_tunes\roseofmay-piano.mid
# Parsing piano_tunes\rufus.mid
# Parsing piano_tunes\Rydia_pc.mid
# Parsing piano_tunes\sandy.mid
# Parsing piano_tunes\sera_.mid
# Parsing piano_tunes\sobf.mid
# Parsing piano_tunes\Still_Alive-1.mid
# Parsing piano_tunes\Suteki_Da_Ne_(Piano_Version).mid
# Parsing piano_tunes\thenightmarebegins.mid
# Parsing piano_tunes\thoughts.mid
# Parsing piano_tunes\tifap.mid
# Parsing piano_tunes\tpirtsd-piano.mid
# Parsing piano_tunes\traitor.mid
# Parsing piano_tunes\ultimafro.mid
# Parsing piano_tunes\ultros.mid
# Parsing piano_tunes\VincentPiano.mid
# Parsing piano_tunes\ViviinAlexandria.mid
# Parsing piano_tunes\waltz_de_choco.mid
# Parsing piano_tunes\Zelda_Overworld.mid
# Parsing piano_tunes\z_aeristhemepiano.mid

# %%
len(notes)
# Out:
# 60866

# %%
with open("notes.pkl","wb") as filepath:
    pickle.dump(notes, filepath)

# %%
with open("notes.pkl","rb") as filepath:
    notes = pickle.load(filepath)

# %%
n_vocab = len(set(notes)) # Unique elements

# %%
print("Total Notes -",len(notes))
print("Unique Notes -",n_vocab)
# Out:
# Total Notes - 60866
# Unique Notes - 359

# %%
print(notes[:100])
# Out:
# ['4+9', 'E2', '4+9', '4+9', '4+9', '4+9', '4+9', '4+9', '4+9', '11+4', '4+9', '11+4', '4+9', '4+9', '4+9', '4+9', '4+9', '0+4', 'E2', '4+9', '0+4', '4+9', '4+9', '4+9', '4+9', '4+9', '9+2', '4+9', '9+2', '9+2', '4+9', '4+9', '4+9', '4+9', '4+9', '4+9', 'E2', '4+9', '4+9', '4+9', '4+9', '4+9', 'E5', 'F5', 'G#5', 'A5', '4+9', '4+9', '5+11', '4+9', '5+11', '4+9', '4+9', '4+9', 'E5', 'F5', 'G#5', 'A5', '4+9', '4+9', '9+0', 'E2', '4+9', '9+0', '4+9', '4+9', '4+9', 'E5', 'F5', 'G#5', 'A5', '4+9', '4+9', '11+2', '4+9', '11+2', '11+2', '4+9', '4+9', '4+9', 'E5', 'F5', 'G#5', 'A5', '4+9', '4+9', '3+7+11', 'E-2', '3+7+11', 'B2', 'G2', '1+5+9', 'F#2', '1+5+9', '3+7+11', 'E-2', '3+7+11', 'G2', 'B2', 'E-3']
